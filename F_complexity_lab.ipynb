# %% [markdown]
# # F: Complexity

# %% [markdown]
# There isn't much for you to do in this lab sheet. Finish it quickly and then make progress with the first continuous assessment.
#
# There are hints and answers in this lab sheet. If you want to be able to see them, then execute the next code cell.

# %%
# %run do_install_HAs.py F_complexity_lab

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_circles
from sklearn.datasets import make_classification

from sklearn.pipeline import Pipeline

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate

from sklearn.linear_model import LogisticRegression

# %%
rng = np.random.RandomState(2)

# %%
def check_fit(model, X_train, y_train, cv, metric):
    scores = cross_validate(model, X_train, y_train, cv=cv, scoring=metric, return_train_score=True, n_jobs=-1)
    return scores["train_score"].mean(), scores["test_score"].mean()

# %% [markdown]
# ## Circles Dataset

# %%
X, y = make_circles(n_samples=200, random_state=rng)

# %%
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.2, stratify=y, random_state=rng)

# %%
fig = plt.figure(figsize=(4,4))
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train)
plt.show()

# %%
logistic_model = Pipeline([
    ("scaler", StandardScaler()),
    ("predictor", LogisticRegression(penalty=None, random_state=rng))
])

# %%
logistic_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('predictor',
#                  LogisticRegression(penalty=None,
#                                     random_state=RandomState(MT19937) at 0x12339BD40))])

# %% [markdown]
# **Exercise 1.** Answer this without writing any code.
#
# Do you think the Logistic Regressor created above will underfit or overfit this training set?

# %% [markdown]
# **Exercise 2.** Now write a line of code to confirm (or disconfirm) your suspicions.

# %% [markdown]
# **Exercise 3.** Copy the `logistic_model` from above. Add one line of code to make it fit the training data better, i.e. to reduce the under/over fitting. (You need an `import` also.)
#
# Write another line of code to fit your new model.
#
# Then write a line of code to check whether your new model is an improvement on the previous one.

# %% [markdown]
# ## Another Dataset

# %%
X, y = make_classification(n_samples=200, n_features=30, random_state=rng)

# %%
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=0.2, stratify=y, random_state=rng)

# %%
logistic_model = Pipeline([
    ("scaler", StandardScaler()),
    ("predictor", LogisticRegression(penalty=None, random_state=rng))
])

# %%
logistic_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('predictor',
#                  LogisticRegression(penalty=None,
#                                     random_state=RandomState(MT19937) at 0x12339BD40))])

# %% [markdown]
# **Exercise 4.** Write a line of code to find out whether this model underfits or overfits this training set.

# %% [markdown]
# **Exercise 5.** Copy the `logistic_model` from above. Add one line of code to make it fit the training data better, i.e. to reduce the under/over fitting. (You need an `import` also.)
#
# Write another line of code to fit your new model.
#
# Then write a line of code to check whether your new model is an improvement on the previous one.
